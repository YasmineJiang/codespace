# %% [markdown]
# <a href="https://colab.research.google.com/github/YasmineJiang/codespace/blob/main/Predictive_Modeling_for_British_Airline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exploratory Data Analysis before Modeling**

# %%
#Libraries import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("customer_booking.csv", encoding="ISO-8859-1")
df[df['booking_complete'] == 1]
# Out:
#        num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 82                  1      Internet  RoundTrip             15              31
# 86                  1      Internet  RoundTrip            156              19
# 94                  1      Internet  RoundTrip            181              87
# 109                 1        Mobile  RoundTrip            127              17
# 122                 1      Internet  RoundTrip             42              17
# ...               ...           ...        ...            ...             ...
# 49972               1      Internet  RoundTrip             33               6
# 49977               2      Internet  RoundTrip             15               6
# 49980               4      Internet  RoundTrip            242               6
# 49984               2      Internet  RoundTrip              7               6
# 49987               3      Internet  RoundTrip            243               6
#
#        flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 82              17        Mon  AKLKUL       Malaysia                    0
# 86              14        Mon  AKLKUL       Malaysia                    1
# 94               2        Tue  AKLKUL      Singapore                    1
# 109             16        Tue  AKLKUL       Malaysia                    1
# 122             14        Tue  AKLKUL       Malaysia                    0
# ...            ...        ...     ...            ...                  ...
# 49972            6        Wed  PENTPE         Taiwan                    1
# 49977           16        Tue  PENTPE       Malaysia                    1
# 49980            9        Tue  PENXIY       Malaysia                    1
# 49984            4        Wed  PERPNH      Australia                    0
# 49987           12        Fri  PERPNH      Australia                    1
#
#        wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# 82                        0                      0             8.83
# 86                        0                      0             8.83
# 94                        0                      1             8.83
# 109                       0                      1             8.83
# 122                       0                      0             8.83
# ...                     ...                    ...              ...
# 49972                     1                      0             4.67
# 49977                     1                      1             4.67
# 49980                     0                      1             5.00
# 49984                     0                      0             5.62
# 49987                     0                      1             5.62
#
#        booking_complete
# 82                    1
# 86                    1
# 94                    1
# 109                   1
# 122                   1
# ...                 ...
# 49972                 1
# 49977                 1
# 49980                 1
# 49984                 1
# 49987                 1
#
# [7478 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   num_passengers         50000 non-null  int64
#  1   sales_channel          50000 non-null  object
#  2   trip_type              50000 non-null  object
#  3   purchase_lead          50000 non-null  int64
#  4   length_of_stay         50000 non-null  int64
#  5   flight_hour            50000 non-null  int64
#  6   flight_day             50000 non-null  object
#  7   route                  50000 non-null  object
#  8   booking_origin         50000 non-null  object
#  9   wants_extra_baggage    50000 non-null  int64
#  10  wants_preferred_seat   50000 non-null  int64
#  11  wants_in_flight_meals  50000 non-null  int64
#  12  flight_duration        50000 non-null  float64
#  13  booking_complete       50000 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 5.3+ MB

# %%
df["flight_day"].unique()
mapping = {
    "Mon": 1,
    "Tue": 2,
    "Wed": 3,
    "Thu": 4,
    "Fri": 5,
    "Sat": 6,
    "Sun": 7,
}
df["flight_day"] = df["flight_day"].map(mapping)

# %%
df.describe()
# Out:
#        num_passengers  purchase_lead  length_of_stay  flight_hour  \
# count    50000.000000   50000.000000     50000.00000  50000.00000
# mean         1.591240      84.940480        23.04456      9.06634
# std          1.020165      90.451378        33.88767      5.41266
# min          1.000000       0.000000         0.00000      0.00000
# 25%          1.000000      21.000000         5.00000      5.00000
# 50%          1.000000      51.000000        17.00000      9.00000
# 75%          2.000000     115.000000        28.00000     13.00000
# max          9.000000     867.000000       778.00000     23.00000
#
#          flight_day  wants_extra_baggage  wants_preferred_seat  \
# count  50000.000000         50000.000000          50000.000000
# mean       3.814420             0.668780              0.296960
# std        1.992792             0.470657              0.456923
# min        1.000000             0.000000              0.000000
# 25%        2.000000             0.000000              0.000000
# 50%        4.000000             1.000000              0.000000
# 75%        5.000000             1.000000              1.000000
# max        7.000000             1.000000              1.000000
#
#        wants_in_flight_meals  flight_duration  booking_complete
# count           50000.000000     50000.000000      50000.000000
# mean                0.427140         7.277561          0.149560
# std                 0.494668         1.496863          0.356643
# min                 0.000000         4.670000          0.000000
# 25%                 0.000000         5.620000          0.000000
# 50%                 0.000000         7.570000          0.000000
# 75%                 1.000000         8.830000          0.000000
# max                 1.000000         9.500000          1.000000

# %%
#Visualizations
#Bar chart for sale channels
channel_count = df['sales_channel'].value_counts()
channel_count.plot(kind='bar')
plt.title('Sale Channel Distribution')
plt.xlabel('Channel')
plt.ylabel('Frequency')
channel_count
# Out:
# Internet    44382
# Mobile       5618
# Name: sales_channel, dtype: int64

# %%
#Distribution of purchase lead
sns.histplot(df['purchase_lead'], kde=True)
plt.title('Distribution of purchase_lead')
plt.xlabel('Value')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
dummy_data = pd.get_dummies(df, columns=['sales_channel','trip_type'])
dummy_data.columns
# Out:
# Index(['num_passengers', 'purchase_lead', 'length_of_stay', 'flight_hour',
#        'flight_day', 'route', 'booking_origin', 'wants_extra_baggage',
#        'wants_preferred_seat', 'wants_in_flight_meals', 'flight_duration',
#        'booking_complete', 'sales_channel_Internet', 'sales_channel_Mobile',
#        'trip_type_CircleTrip', 'trip_type_OneWay', 'trip_type_RoundTrip'],
#       dtype='object')

# %%
#Heatmap
correlation_matrix = dummy_data.corr()
plt.figure(figsize=(20, 15))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <ipython-input-9-c74a3a2b5137>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = dummy_data.corr()
# <Axes: >

# %% [markdown]
# # **Data Modeling**

# %%
#Import machine learning libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score

# %%
columns = list(dummy_data.columns)
columns
# Out:
# ['num_passengers',
#  'purchase_lead',
#  'length_of_stay',
#  'flight_hour',
#  'flight_day',
#  'route',
#  'booking_origin',
#  'wants_extra_baggage',
#  'wants_preferred_seat',
#  'wants_in_flight_meals',
#  'flight_duration',
#  'booking_complete',
#  'sales_channel_Internet',
#  'sales_channel_Mobile',
#  'trip_type_CircleTrip',
#  'trip_type_OneWay',
#  'trip_type_RoundTrip']

# %%
X = dummy_data[['num_passengers',
 'purchase_lead',
 'length_of_stay',
 'flight_hour',
 'flight_day',
 'wants_extra_baggage',
 'wants_preferred_seat',
 'wants_in_flight_meals',
 'flight_duration',
 'sales_channel_Internet',
 'sales_channel_Mobile',
 'trip_type_CircleTrip',
 'trip_type_OneWay',
 'trip_type_RoundTrip']]
y = dummy_data['booking_complete']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

predictions = rf.predict(X_test)

# %% [markdown]
# # **Model Evaluation(Random Forest)**

# %%
#Confusion Matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, predictions))
# Out:
# Confusion Matrix:
# [[12579   150]
#  [ 2149   122]]

# %%
#Cross validation
scores = cross_val_score(rf, X, y, cv=5)  # 5-fold cross-validation
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

print("\nClassification Report:")
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 0.65 (+/- 0.42)
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.92     12729
#            1       0.45      0.05      0.10      2271
#
#     accuracy                           0.85     15000
#    macro avg       0.65      0.52      0.51     15000
# weighted avg       0.79      0.85      0.79     15000

# %%
#Feature importance analysis
importances = rf.feature_importances_

# Convert the importances into a DataFrame
feature_importance = pd.DataFrame({'feature': X.columns, 'importance': importances})

# Sort the DataFrame to plot it
feature_importance = feature_importance.sort_values('importance', ascending=False)

# Create a bar plot for feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='importance', y='feature', data=feature_importance)
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()
feature_importance
# Out:
#                    feature  importance
# 1            purchase_lead    0.286941
# 3              flight_hour    0.196538
# 2           length_of_stay    0.165758
# 8          flight_duration    0.124629
# 4               flight_day    0.112863
# 0           num_passengers    0.057560
# 7    wants_in_flight_meals    0.019152
# 5      wants_extra_baggage    0.013626
# 6     wants_preferred_seat    0.013455
# 9   sales_channel_Internet    0.003684
# 10    sales_channel_Mobile    0.003569
# 13     trip_type_RoundTrip    0.001049
# 12        trip_type_OneWay    0.000706
# 11    trip_type_CircleTrip    0.000472
